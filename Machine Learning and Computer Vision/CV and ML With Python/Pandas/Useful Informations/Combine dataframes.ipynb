# %%
import pandas as pd

# %% [markdown]
# ## Combine Side by Side
#
# Merge or Join: Merge can do everything and more than Join

# %%
df1 = pd.DataFrame(
    {
      'person': ['Person 1', 'Person 2', 'Person 3'],
      'Age': ['22', '22', '23'],
      'city': ['City 1', 'City 2', 'City 2']
    })

display(df1)
# Out:
#      person Age    city
# 0  Person 1  22  City 1
# 1  Person 2  22  City 2
# 2  Person 3  23  City 2

# %%
df2 = pd.DataFrame({
                    'city': ['City 1', 'City 2', 'City 3'],
                    'state': ['ST1', 'ST2', 'ST3']
                   })

display(df2)
# Out:
#      city state
# 0  City 1   ST1
# 1  City 2   ST2
# 2  City 3   ST3

# %% [markdown]
# ### Merge

# %%
# The function recognizes that city is the same for both df, and automatically joins using this column as a key.
pd.merge(df1, df2)
# Out:
#      person Age    city state
# 0  Person 1  22  City 1   ST1
# 1  Person 2  22  City 2   ST2
# 2  Person 3  23  City 2   ST2

# %%
pd.merge(df1, df2)
# Out:
#      person Age    city state
# 0  Person 1  22  City 1   ST1
# 1  Person 2  22  City 2   ST2
# 2  Person 3  23  City 2   ST2

# %% [markdown]
# ### Merge with two keys

# %%
df1 = pd.DataFrame(
    {
      'person': ['Person 1', 'Person 2', 'Person 3'],
      'Age': ['22', '22', '23'],
      'city': ['City 1', 'City 2', 'City 2'],
       'id' : [1, 2, 3]
    })

display(df1)
# Out:
#      person Age    city  id
# 0  Person 1  22  City 1   1
# 1  Person 2  22  City 2   2
# 2  Person 3  23  City 2   3

# %%
df2 = pd.DataFrame({
                    'id' : [1, 2, 3],
                    'city': ['City 1', 'City 2', 'City 3'],
                    'state': ['ST1', 'ST2', 'ST3']
                   })

display(df2)
# Out:
#    id    city state
# 0   1  City 1   ST1
# 1   2  City 2   ST2
# 2   3  City 3   ST3

# %%
# Row where person 3 is placed is removed, because id == 3 but, city is city 2.
# in df2, the city in this is case is city 3. It does not match.
# in order to be added, it must matches all the shared colluns
pd.merge(df1, df2)
# Out:
#      person Age    city  id state
# 0  Person 1  22  City 1   1   ST1
# 1  Person 2  22  City 2   2   ST2

# %%
# To consider only one collunm, we must specify it on a argument
# _x = left df, _y = right df
pd.merge(df1, df2, on='id') # to specify two, ['id', 'city']
# Out:
#      person Age  city_x  id  city_y state
# 0  Person 1  22  City 1   1  City 1   ST1
# 1  Person 2  22  City 2   2  City 2   ST2
# 2  Person 3  23  City 2   3  City 3   ST3

# %%
pd.merge(df1, df2, on='id', suffixes=['_l', '_r'])
# Out:
#      person Age  city_l  id  city_r state
# 0  Person 1  22  City 1   1  City 1   ST1
# 1  Person 2  22  City 2   2  City 2   ST2
# 2  Person 3  23  City 2   3  City 3   ST3

# %%
pd.merge(df1, df2, on='id', suffixes=['_l', '_r'], left_index=True, right_index=True)
# Out:
#      person Age  city_l  id  city_r state
# 0  Person 1  22  City 1   1  City 1   ST1
# 1  Person 2  22  City 2   2  City 2   ST2
# 2  Person 3  23  City 2   3  City 3   ST3

# %%
df3 = pd.DataFrame(
    {
      'person': ['Person 1', 'Person 2', 'Person 3'],
      'Age': ['22', '22', '23'],
      'city_1': ['City 1', 'City 2', 'City 2'],
       'id' : [1, 2, 3]
    })

display(df3)
# Out:
#      person Age  city_1  id
# 0  Person 1  22  City 1   1
# 1  Person 2  22  City 2   2
# 2  Person 3  23  City 2   3

# %%
df4 = pd.DataFrame(
    {
      'city_2': ['City 1', 'City 2', 'City 3'],
       'id' : [1, 2, 3]
    })

display(df4)
# Out:
#    city_2  id
# 0  City 1   1
# 1  City 2   2
# 2  City 3   3

# %%
pd.merge(df3, df4, suffixes=['_l', '_r'], left_on=['id', 'city_1'], right_on=['id','city_2'])
# Out:
#      person Age  city_1  id  city_2
# 0  Person 1  22  City 1   1  City 1
# 1  Person 2  22  City 2   2  City 2

# %% [markdown]
# ### Outer join

# %%
pd.merge(df1, df2, on=['id', 'city'], suffixes=['_l', '_r'], how='outer')
# Out:
#      person  Age    city  id state
# 0  Person 1   22  City 1   1   ST1
# 1  Person 2   22  City 2   2   ST2
# 2  Person 3   23  City 2   3   NaN
# 3       NaN  NaN  City 3   3   ST3

# %% [markdown]
# ### Inner join

# %%
pd.merge(df1, df2, on= ['id', 'city'], suffixes=['_l', '_r'], how='inner')
# Out:
#      person Age    city  id state
# 0  Person 1  22  City 1   1   ST1
# 1  Person 2  22  City 2   2   ST2

# %% [markdown]
# ### Left join

# %%
pd.merge(df1, df2, on= ['id', 'city'], suffixes=['_l', '_r'], how='left')
# Out:
#      person Age    city  id state
# 0  Person 1  22  City 1   1   ST1
# 1  Person 2  22  City 2   2   ST2
# 2  Person 3  23  City 2   3   NaN

# %% [markdown]
# ### Right join

# %%
pd.merge(df1, df2, on= ['id', 'city'], suffixes=['_l', '_r'], how='right')
# Out:
#      person  Age    city  id state
# 0  Person 1   22  City 1   1   ST1
# 1  Person 2   22  City 2   2   ST2
# 2       NaN  NaN  City 3   3   ST3

# %% [markdown]
# ## Concatenation (or append)

# %%
pd.concat([df1, df3]) # index is not reset, it's 0,1,2, 0,1,2
# Out:
#      person Age    city  id  city_1
# 0  Person 1  22  City 1   1     NaN
# 1  Person 2  22  City 2   2     NaN
# 2  Person 3  23  City 2   3     NaN
# 0  Person 1  22     NaN   1  City 1
# 1  Person 2  22     NaN   2  City 2
# 2  Person 3  23     NaN   3  City 2

# %%
pd.concat([df1, df3], ignore_index=True)
# Out:
#      person Age    city  id  city_1
# 0  Person 1  22  City 1   1     NaN
# 1  Person 2  22  City 2   2     NaN
# 2  Person 3  23  City 2   3     NaN
# 3  Person 1  22     NaN   1  City 1
# 4  Person 2  22     NaN   2  City 2
# 5  Person 3  23     NaN   3  City 2

# %%
# keep index col
df = pd.concat([df1, df3])
df.reset_index(inplace=True)
display(df)
# Out:
#    index    person Age    city  id  city_1
# 0      0  Person 1  22  City 1   1     NaN
# 1      1  Person 2  22  City 2   2     NaN
# 2      2  Person 3  23  City 2   3     NaN
# 3      0  Person 1  22     NaN   1  City 1
# 4      1  Person 2  22     NaN   2  City 2
# 5      2  Person 3  23     NaN   3  City 2

# %%
# discard index col
df = pd.concat([df1, df3])
df.reset_index(inplace=True, drop=True)
display(df)
# Out:
#      person Age    city  id  city_1
# 0  Person 1  22  City 1   1     NaN
# 1  Person 2  22  City 2   2     NaN
# 2  Person 3  23  City 2   3     NaN
# 3  Person 1  22     NaN   1  City 1
# 4  Person 2  22     NaN   2  City 2
# 5  Person 3  23     NaN   3  City 2

# %%
df1.append(df3, sort=True)
# Out:
#   Age    city  city_1  id    person
# 0  22  City 1     NaN   1  Person 1
# 1  22  City 2     NaN   2  Person 2
# 2  23  City 2     NaN   3  Person 3
# 0  22     NaN  City 1   1  Person 1
# 1  22     NaN  City 2   2  Person 2
# 2  23     NaN  City 2   3  Person 3

# %% [markdown]
# ## Using a real dataset

# %%
data = pd.read_csv('data/train.csv')
data.head(6)
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
# 5     2          NaN    3     266       0       2       5       6       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
# 5             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# 3  9238e4f44c71a75282e62f7136c6b240         0
# 4  95481e953f8aed9ec3d16fc4509537e8         0
# 5  22fe332bf9c924d4718005891c63fbed         0
#
#                                          Description      PetID PhotoAmt  \
# 0  Nibble is a 3+ month old ball of cuteness. He ...  86e1089a3      1.0
# 1  I just found it alone yesterday near my apartm...  6296e909a      2.0
# 2  Their pregnant mother was dumped by her irresp...  3422e4906      7.0
# 3  Good guard dog, very alert, active, obedience ...  5842f1ff5      8.0
# 4  This handsome yet cute boy is up for adoption....  850a43f90      3.0
# 5  This is a stray kitten that came to my house. ...  d24c30b4b      2.0
#
#    AdoptionSpeed
# 0              2
# 1              0
# 2              3
# 3              2
# 4              2
# 5              2
#
# [6 rows x 24 columns]

# %%
state_labels = pd.read_csv('data/state_labels.csv')
state_labels.head()
# Out:
#    StateID     StateName
# 0    41336         Johor
# 1    41325         Kedah
# 2    41367      Kelantan
# 3    41401  Kuala Lumpur
# 4    41415        Labuan

# %%
breed_labels = pd.read_csv('data/BreedLabels.csv')
breed_labels.head()
# Out:
#    BreedID  Type         BreedName
# 0        1     1     Affenpinscher
# 1        2     1      Afghan Hound
# 2        3     1  Airedale Terrier
# 3        4     1            Akbash
# 4        5     1             Akita

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14993 entries, 0 to 14992
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Breed1         14993 non-null  int64
#  4   Breed2         14993 non-null  int64
#  5   Gender         14993 non-null  int64
#  6   Color1         14993 non-null  int64
#  7   Color2         14993 non-null  int64
#  8   Color3         14993 non-null  int64
#  9   MaturitySize   14993 non-null  int64
#  10  FurLength      14993 non-null  int64
#  11  Vaccinated     14993 non-null  int64
#  12  Dewormed       14993 non-null  int64
#  13  Sterilized     14993 non-null  int64
#  14  Health         14993 non-null  int64
#  15  Quantity       14993 non-null  int64
#  16  Fee            14993 non-null  int64
#  17  State          14993 non-null  int64
#  18  RescuerID      14993 non-null  object
#  19  VideoAmt       14993 non-null  int64
#  20  Description    14981 non-null  object
#  21  PetID          14993 non-null  object
#  22  PhotoAmt       14993 non-null  float64
#  23  AdoptionSpeed  14993 non-null  int64
# dtypes: float64(1), int64(19), object(4)
# memory usage: 2.7+ MB

# %%
data[['Breed1', 'Breed2']]
# Out:
#        Breed1  Breed2
# 0         299       0
# 1         265       0
# 2         307       0
# 3         307       0
# 4         307       0
# ...       ...     ...
# 14988     266       0
# 14989     265     264
# 14990     265     266
# 14991     266       0
# 14992     307     307
#
# [14993 rows x 2 columns]

# %%
merge_breed = data.merge(breed_labels, left_on=['Breed1'], right_on=['BreedID'], how='left')
merge_breed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Breed1         14993 non-null  int64
#  4   Breed2         14993 non-null  int64
#  5   Gender         14993 non-null  int64
#  6   Color1         14993 non-null  int64
#  7   Color2         14993 non-null  int64
#  8   Color3         14993 non-null  int64
#  9   MaturitySize   14993 non-null  int64
#  10  FurLength      14993 non-null  int64
#  11  Vaccinated     14993 non-null  int64
#  12  Dewormed       14993 non-null  int64
#  13  Sterilized     14993 non-null  int64
#  14  Health         14993 non-null  int64
#  15  Quantity       14993 non-null  int64
#  16  Fee            14993 non-null  int64
#  17  State          14993 non-null  int64
#  18  RescuerID      14993 non-null  object
#  19  VideoAmt       14993 non-null  int64
#  20  Description    14981 non-null  object
#  21  PetID          14993 non-null  object
#  22  PhotoAmt       14993 non-null  float64
#  23  AdoptionSpeed  14993 non-null  int64
#  24  BreedID        14988 non-null  float64
#  25  Type_y         14988 non-null  float64
#  26  BreedName      14988 non-null  object
# dtypes: float64(3), int64(19), object(5)
# memory usage: 3.2+ MB

# %%
display(merge_breed[['Breed1', 'Breed2', 'BreedName', 'Type_x', 'Type_y']])
merge_breed.drop(inplace=True, axis=1, columns=['Type_y', 'Breed1'])
# Out:
#        Breed1  Breed2             BreedName  Type_x  Type_y
# 0         299       0                 Tabby       2     2.0
# 1         265       0  Domestic Medium Hair       2     2.0
# 2         307       0           Mixed Breed       1     1.0
# 3         307       0           Mixed Breed       1     1.0
# 4         307       0           Mixed Breed       1     1.0
# ...       ...     ...                   ...     ...     ...
# 14988     266       0   Domestic Short Hair       2     2.0
# 14989     265     264  Domestic Medium Hair       2     2.0
# 14990     265     266  Domestic Medium Hair       2     2.0
# 14991     266       0   Domestic Short Hair       2     2.0
# 14992     307     307           Mixed Breed       1     1.0
#
# [14993 rows x 5 columns]

# %%
breed_labels.loc[breed_labels['BreedID'] == 307]
# Out:
#      BreedID  Type    BreedName
# 240      307     1  Mixed Breed

# %%
merge_breed2 = merge_breed.merge(breed_labels, left_on=['Breed2'], right_on=['BreedID'], how='left') # to keep breed0
merge_breed2.info()
merge_breed2.drop('Type', inplace=True, axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Breed2         14993 non-null  int64
#  4   Gender         14993 non-null  int64
#  5   Color1         14993 non-null  int64
#  6   Color2         14993 non-null  int64
#  7   Color3         14993 non-null  int64
#  8   MaturitySize   14993 non-null  int64
#  9   FurLength      14993 non-null  int64
#  10  Vaccinated     14993 non-null  int64
#  11  Dewormed       14993 non-null  int64
#  12  Sterilized     14993 non-null  int64
#  13  Health         14993 non-null  int64
#  14  Quantity       14993 non-null  int64
#  15  Fee            14993 non-null  int64
#  16  State          14993 non-null  int64
#  17  RescuerID      14993 non-null  object
#  18  VideoAmt       14993 non-null  int64
#  19  Description    14981 non-null  object
#  20  PetID          14993 non-null  object
#  21  PhotoAmt       14993 non-null  float64
#  22  AdoptionSpeed  14993 non-null  int64
#  23  BreedID_x      14988 non-null  float64
#  24  BreedName_x    14988 non-null  object
#  25  BreedID_y      4231 non-null   float64
#  26  Type           4231 non-null   float64
#  27  BreedName_y    4231 non-null   object
# dtypes: float64(4), int64(18), object(6)
# memory usage: 3.3+ MB

# %%
display(merge_breed2[['Breed2', 'BreedName_x', 'BreedName_y', 'Type_x', 'BreedID_x', 'BreedID_y']])
# Out:
#        Breed2           BreedName_x          BreedName_y  Type_x  BreedID_x  \
# 0           0                 Tabby                  NaN       2      299.0
# 1           0  Domestic Medium Hair                  NaN       2      265.0
# 2           0           Mixed Breed                  NaN       1      307.0
# 3           0           Mixed Breed                  NaN       1      307.0
# 4           0           Mixed Breed                  NaN       1      307.0
# ...       ...                   ...                  ...     ...        ...
# 14988       0   Domestic Short Hair                  NaN       2      266.0
# 14989     264  Domestic Medium Hair   Domestic Long Hair       2      265.0
# 14990     266  Domestic Medium Hair  Domestic Short Hair       2      265.0
# 14991       0   Domestic Short Hair                  NaN       2      266.0
# 14992     307           Mixed Breed          Mixed Breed       1      307.0
#
#        BreedID_y
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 14988        NaN
# 14989      264.0
# 14990      266.0
# 14991        NaN
# 14992      307.0
#
# [14993 rows x 6 columns]

# %%
breed_labels.loc[breed_labels['BreedID'] == 264]
# Out:
#      BreedID  Type           BreedName
# 264      264     2  Domestic Long Hair

# %%
merge_breed2['BreedName_y'].isna().sum()
# Out:
# 10762

# %%
merge_breed2['BreedName_x'].isna().sum()
# Out:
# 5

# %%
# where breed2 is 0 is the same as breed1
merge_breed2['BreedName_y'] = merge_breed2['BreedName_y'].fillna(merge_breed2['BreedName_x'])

# %%
display(merge_breed2[['Breed2', 'BreedName_x', 'BreedName_y', 'Type_x', 'BreedID_x', 'BreedID_y']])
# Out:
#        Breed2           BreedName_x           BreedName_y  Type_x  BreedID_x  \
# 0           0                 Tabby                 Tabby       2      299.0
# 1           0  Domestic Medium Hair  Domestic Medium Hair       2      265.0
# 2           0           Mixed Breed           Mixed Breed       1      307.0
# 3           0           Mixed Breed           Mixed Breed       1      307.0
# 4           0           Mixed Breed           Mixed Breed       1      307.0
# ...       ...                   ...                   ...     ...        ...
# 14988       0   Domestic Short Hair   Domestic Short Hair       2      266.0
# 14989     264  Domestic Medium Hair    Domestic Long Hair       2      265.0
# 14990     266  Domestic Medium Hair   Domestic Short Hair       2      265.0
# 14991       0   Domestic Short Hair   Domestic Short Hair       2      266.0
# 14992     307           Mixed Breed           Mixed Breed       1      307.0
#
#        BreedID_y
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 14988        NaN
# 14989      264.0
# 14990      266.0
# 14991        NaN
# 14992      307.0
#
# [14993 rows x 6 columns]

# %%
merge_breed2['BreedName_y'].isna().sum()
# Out:
# 0

# %%
merge_breed2['BreedID_y'].isna().sum()
# Out:
# 10762

# %%
merge_breed2.drop(['Breed2', 'BreedID_y', 'BreedID_x'], inplace=True, axis=1)
merge_breed2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  State          14993 non-null  int64
#  16  RescuerID      14993 non-null  object
#  17  VideoAmt       14993 non-null  int64
#  18  Description    14981 non-null  object
#  19  PetID          14993 non-null  object
#  20  PhotoAmt       14993 non-null  float64
#  21  AdoptionSpeed  14993 non-null  int64
#  22  BreedName_x    14988 non-null  object
#  23  BreedName_y    14993 non-null  object
# dtypes: float64(1), int64(17), object(6)
# memory usage: 2.9+ MB

# %%
merge_breed2[['State']]
# Out:
#        State
# 0      41326
# 1      41401
# 2      41326
# 3      41401
# 4      41326
# ...      ...
# 14988  41326
# 14989  41326
# 14990  41326
# 14991  41336
# 14992  41332
#
# [14993 rows x 1 columns]

# %%
merged_state = merge_breed2.merge(state_labels, left_on='State', right_on='StateID')
merged_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  State          14993 non-null  int64
#  16  RescuerID      14993 non-null  object
#  17  VideoAmt       14993 non-null  int64
#  18  Description    14981 non-null  object
#  19  PetID          14993 non-null  object
#  20  PhotoAmt       14993 non-null  float64
#  21  AdoptionSpeed  14993 non-null  int64
#  22  BreedName_x    14988 non-null  object
#  23  BreedName_y    14993 non-null  object
#  24  StateID        14993 non-null  int64
#  25  StateName      14993 non-null  object
# dtypes: float64(1), int64(18), object(7)
# memory usage: 3.1+ MB

# %%
merged_state[['StateID', 'StateName', 'State']]
# Out:
#        StateID StateName  State
# 0        41326  Selangor  41326
# 1        41326  Selangor  41326
# 2        41326  Selangor  41326
# 3        41326  Selangor  41326
# 4        41326  Selangor  41326
# ...        ...       ...    ...
# 14988    41367  Kelantan  41367
# 14989    41367  Kelantan  41367
# 14990    41415    Labuan  41415
# 14991    41415    Labuan  41415
# 14992    41415    Labuan  41415
#
# [14993 rows x 3 columns]

# %%
state_labels[state_labels['StateID'] == 41326]
# Out:
#     StateID StateName
# 13    41326  Selangor

# %%
final_df = merged_state.drop(['StateID', 'State'], axis=1)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  RescuerID      14993 non-null  object
#  16  VideoAmt       14993 non-null  int64
#  17  Description    14981 non-null  object
#  18  PetID          14993 non-null  object
#  19  PhotoAmt       14993 non-null  float64
#  20  AdoptionSpeed  14993 non-null  int64
#  21  BreedName_x    14988 non-null  object
#  22  BreedName_y    14993 non-null  object
#  23  StateName      14993 non-null  object
# dtypes: float64(1), int64(16), object(7)
# memory usage: 2.9+ MB

# %%
final_df[['Color1', 'Color2', 'Color3']]
# Out:
#        Color1  Color2  Color3
# 0           1       7       0
# 1           2       7       0
# 2           1       0       0
# 3           5       6       0
# 4           1       0       0
# ...       ...     ...     ...
# 14988       1       0       0
# 14989       7       0       0
# 14990       5       0       0
# 14991       5       0       0
# 14992       3       6       7
#
# [14993 rows x 3 columns]

# %%
color_labels = pd.read_csv('data/ColorLabels.csv')
color_labels
# Out:
#    ColorID ColorName
# 0        1     Black
# 1        2     Brown
# 2        3    Golden
# 3        4    Yellow
# 4        5     Cream
# 5        6      Gray
# 6        7     White

# %%
final_df = final_df.merge(color_labels, left_on='Color1', right_on='ColorID', how='left') # to keep the 0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  RescuerID      14993 non-null  object
#  16  VideoAmt       14993 non-null  int64
#  17  Description    14981 non-null  object
#  18  PetID          14993 non-null  object
#  19  PhotoAmt       14993 non-null  float64
#  20  AdoptionSpeed  14993 non-null  int64
#  21  BreedName_x    14988 non-null  object
#  22  BreedName_y    14993 non-null  object
#  23  StateName      14993 non-null  object
#  24  ColorID        14993 non-null  int64
#  25  ColorName      14993 non-null  object
# dtypes: float64(1), int64(17), object(8)
# memory usage: 3.1+ MB

# %%
final_df = final_df.merge(color_labels, left_on='Color2', right_on='ColorID', how='left') # to keep the 0
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  RescuerID      14993 non-null  object
#  16  VideoAmt       14993 non-null  int64
#  17  Description    14981 non-null  object
#  18  PetID          14993 non-null  object
#  19  PhotoAmt       14993 non-null  float64
#  20  AdoptionSpeed  14993 non-null  int64
#  21  BreedName_x    14988 non-null  object
#  22  BreedName_y    14993 non-null  object
#  23  StateName      14993 non-null  object
#  24  ColorID_x      14993 non-null  int64
#  25  ColorName_x    14993 non-null  object
#  26  ColorID_y      10522 non-null  float64
#  27  ColorName_y    10522 non-null  object
# dtypes: float64(2), int64(17), object(9)
# memory usage: 3.3+ MB

# %%
final_df = final_df.merge(color_labels, left_on='Color3', right_on='ColorID', how='left') # to keep the 0
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   Color1         14993 non-null  int64
#  5   Color2         14993 non-null  int64
#  6   Color3         14993 non-null  int64
#  7   MaturitySize   14993 non-null  int64
#  8   FurLength      14993 non-null  int64
#  9   Vaccinated     14993 non-null  int64
#  10  Dewormed       14993 non-null  int64
#  11  Sterilized     14993 non-null  int64
#  12  Health         14993 non-null  int64
#  13  Quantity       14993 non-null  int64
#  14  Fee            14993 non-null  int64
#  15  RescuerID      14993 non-null  object
#  16  VideoAmt       14993 non-null  int64
#  17  Description    14981 non-null  object
#  18  PetID          14993 non-null  object
#  19  PhotoAmt       14993 non-null  float64
#  20  AdoptionSpeed  14993 non-null  int64
#  21  BreedName_x    14988 non-null  object
#  22  BreedName_y    14993 non-null  object
#  23  StateName      14993 non-null  object
#  24  ColorID_x      14993 non-null  int64
#  25  ColorName_x    14993 non-null  object
#  26  ColorID_y      10522 non-null  float64
#  27  ColorName_y    10522 non-null  object
#  28  ColorID        4389 non-null   float64
#  29  ColorName      4389 non-null   object
# dtypes: float64(3), int64(17), object(10)
# memory usage: 3.5+ MB

# %%
final_df[['Color1', 'Color2', 'Color3', 'ColorID_x', 'ColorName_x', 'ColorID_y', 'ColorName_y', 'ColorID', 'ColorName']]
# Out:
#        Color1  Color2  Color3  ColorID_x ColorName_x  ColorID_y ColorName_y  \
# 0           1       7       0          1       Black        7.0       White
# 1           2       7       0          2       Brown        7.0       White
# 2           1       0       0          1       Black        NaN         NaN
# 3           5       6       0          5       Cream        6.0        Gray
# 4           1       0       0          1       Black        NaN         NaN
# ...       ...     ...     ...        ...         ...        ...         ...
# 14988       1       0       0          1       Black        NaN         NaN
# 14989       7       0       0          7       White        NaN         NaN
# 14990       5       0       0          5       Cream        NaN         NaN
# 14991       5       0       0          5       Cream        NaN         NaN
# 14992       3       6       7          3      Golden        6.0        Gray
#
#        ColorID ColorName
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ...        ...       ...
# 14988      NaN       NaN
# 14989      NaN       NaN
# 14990      NaN       NaN
# 14991      NaN       NaN
# 14992      7.0     White
#
# [14993 rows x 9 columns]

# %%
final_df.drop(inplace=True, axis=1, columns=['ColorID_x', 'ColorID_y', 'ColorID', 'Color1', 'Color2', 'Color3'])

# %%
final_df['ColorName_y'] = \
    final_df['ColorName_y'].fillna(final_df['ColorName_x']) # Color2 when is 0, it's going to be the same as color 1

# %%
final_df[['ColorName_x', 'ColorName_y', 'ColorName']]
# Out:
#       ColorName_x ColorName_y ColorName
# 0           Black       White       NaN
# 1           Brown       White       NaN
# 2           Black       Black       NaN
# 3           Cream        Gray       NaN
# 4           Black       Black       NaN
# ...           ...         ...       ...
# 14988       Black       Black       NaN
# 14989       White       White       NaN
# 14990       Cream       Cream       NaN
# 14991       Cream       Cream       NaN
# 14992      Golden        Gray     White
#
# [14993 rows x 3 columns]

# %%
final_df['ColorName'] = \
    final_df['ColorName'].fillna(final_df['ColorName_y']) # Color3 when is 0, it's going to be the same as color 2

# %%
final_df[['ColorName_x', 'ColorName_y', 'ColorName']]
# Out:
#       ColorName_x ColorName_y ColorName
# 0           Black       White     White
# 1           Brown       White     White
# 2           Black       Black     Black
# 3           Cream        Gray      Gray
# 4           Black       Black     Black
# ...           ...         ...       ...
# 14988       Black       Black     Black
# 14989       White       White     White
# 14990       Cream       Cream     Cream
# 14991       Cream       Cream     Cream
# 14992      Golden        Gray     White
#
# [14993 rows x 3 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type_x         14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   MaturitySize   14993 non-null  int64
#  5   FurLength      14993 non-null  int64
#  6   Vaccinated     14993 non-null  int64
#  7   Dewormed       14993 non-null  int64
#  8   Sterilized     14993 non-null  int64
#  9   Health         14993 non-null  int64
#  10  Quantity       14993 non-null  int64
#  11  Fee            14993 non-null  int64
#  12  RescuerID      14993 non-null  object
#  13  VideoAmt       14993 non-null  int64
#  14  Description    14981 non-null  object
#  15  PetID          14993 non-null  object
#  16  PhotoAmt       14993 non-null  float64
#  17  AdoptionSpeed  14993 non-null  int64
#  18  BreedName_x    14988 non-null  object
#  19  BreedName_y    14993 non-null  object
#  20  StateName      14993 non-null  object
#  21  ColorName_x    14993 non-null  object
#  22  ColorName_y    14993 non-null  object
#  23  ColorName      14993 non-null  object
# dtypes: float64(1), int64(13), object(10)
# memory usage: 2.9+ MB

# %%
final_df.rename(columns={
    'Type_x' : 'Type',
    'BreedName_x' : "Breed1",
    'BreedName_y' : "Breed2",
    'ColorName_x' : "Color1",
    'ColorName_y' : "Color2",
    'ColorName'   : "Color3"
}, inplace=True)
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14993 entries, 0 to 14992
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           14993 non-null  int64
#  1   Name           13736 non-null  object
#  2   Age            14993 non-null  int64
#  3   Gender         14993 non-null  int64
#  4   MaturitySize   14993 non-null  int64
#  5   FurLength      14993 non-null  int64
#  6   Vaccinated     14993 non-null  int64
#  7   Dewormed       14993 non-null  int64
#  8   Sterilized     14993 non-null  int64
#  9   Health         14993 non-null  int64
#  10  Quantity       14993 non-null  int64
#  11  Fee            14993 non-null  int64
#  12  RescuerID      14993 non-null  object
#  13  VideoAmt       14993 non-null  int64
#  14  Description    14981 non-null  object
#  15  PetID          14993 non-null  object
#  16  PhotoAmt       14993 non-null  float64
#  17  AdoptionSpeed  14993 non-null  int64
#  18  Breed1         14988 non-null  object
#  19  Breed2         14993 non-null  object
#  20  StateName      14993 non-null  object
#  21  Color1         14993 non-null  object
#  22  Color2         14993 non-null  object
#  23  Color3         14993 non-null  object
# dtypes: float64(1), int64(13), object(10)
# memory usage: 2.9+ MB

# %%
final_df.head()
# Out:
#    Type    Name  Age  Gender  MaturitySize  FurLength  Vaccinated  Dewormed  \
# 0     2  Nibble    3       1             1          1           2         2
# 1     1  Brisco    1       1             2          2           1         1
# 2     1  Hunter    1       1             2          1           2         2
# 3     2     NaN    3       2             2          1           2         2
# 4     2   BULAT   12       1             2          3           2         2
#
#    Sterilized  Health  ...                                        Description  \
# 0           2       1  ...  Nibble is a 3+ month old ball of cuteness. He ...
# 1           2       1  ...  Their pregnant mother was dumped by her irresp...
# 2           2       1  ...  This handsome yet cute boy is up for adoption....
# 3           2       1  ...  This is a stray kitten that came to my house. ...
# 4           3       1  ...  anyone within the area of ipoh or taiping who ...
#
#        PetID PhotoAmt  AdoptionSpeed               Breed1  \
# 0  86e1089a3      1.0              2                Tabby
# 1  3422e4906      7.0              3          Mixed Breed
# 2  850a43f90      3.0              2          Mixed Breed
# 3  d24c30b4b      2.0              2  Domestic Short Hair
# 4  1caa6fcdb      3.0              1   Domestic Long Hair
#
#                 Breed2  StateName  Color1 Color2 Color3
# 0                Tabby   Selangor   Black  White  White
# 1          Mixed Breed   Selangor   Brown  White  White
# 2          Mixed Breed   Selangor   Black  Black  Black
# 3  Domestic Short Hair   Selangor   Cream   Gray   Gray
# 4   Domestic Long Hair   Selangor   Black  Black  Black
#
# [5 rows x 24 columns]
