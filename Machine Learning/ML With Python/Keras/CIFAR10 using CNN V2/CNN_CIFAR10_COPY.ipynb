# %%
# This is a dataset of 50,000 32x32 color training images and 10,000 test images, labeled over 10 categories
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# This is a dataset of 50,000 32x32 color training images and 10,000 test images, labeled over 10 categories
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.5, stratify=y_train)

# %%
print(len(y_train), len(y_val), len(y_test))
# Out:
# 25000 25000 10000

# %%
plt.imshow(x_train[0])
plt.show()

# %%
plt.subplot(221)
plt.imshow(x_train[0])
plt.subplot(222)
plt.imshow(x_train[1])
plt.subplot(223)
plt.imshow(x_train[2])
plt.subplot(224)
plt.imshow(x_train[3])
plt.show()

# %%
# need to specify 32x32 and 3 channels since it's a colored dataset
x_train = x_train.reshape(x_train.shape[0], 32, 32, 3).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 32, 32, 3).astype('float32')
x_val = x_val.reshape(x_val.shape[0], 32, 32, 3).astype('float32')

# %%
# need to normalize values 
x_train = x_train / 255
x_test = x_test / 255
x_val = x_val / 255

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils

# %%
y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)
y_test = np_utils.to_categorical(y_test)

num_classes = y_test.shape[1]

print(num_classes)
# Out:
# 10

# %%
def baseline_model():
  model = Sequential()
  model.add(Conv2D(68, (3, 3), input_shape=(32, 32, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(68, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))
  model.add(Dropout(0.3))
  model.add(Conv2D(120, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size = (2, 2)))
  model.add(Flatten())
  model.add(Dense(700, activation='relu'))
  model.add(Dropout(0.3))
  model.add(Dense(540, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes, activation='softmax'))
  model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
model = baseline_model()

# %%
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=100, batch_size=260)
# Out:
# Epoch 1/100
# 97/97 [==============================] - 78s 802ms/step - loss: 0.1121 - accuracy: 0.9627 - val_loss: 1.2648 - val_accuracy: 0.7402
# Epoch 2/100
# 97/97 [==============================] - 78s 804ms/step - loss: 0.1070 - accuracy: 0.9638 - val_loss: 1.2896 - val_accuracy: 0.7385
# Epoch 3/100
# 97/97 [==============================] - 78s 804ms/step - loss: 0.1154 - accuracy: 0.9619 - val_loss: 1.2922 - val_accuracy: 0.7409
# Epoch 4/100
# 97/97 [==============================] - 78s 804ms/step - loss: 0.1241 - accuracy: 0.9579 - val_loss: 1.2883 - val_accuracy: 0.7418
# Epoch 5/100
# 97/97 [==============================] - 78s 809ms/step - loss: 0.1109 - accuracy: 0.9635 - val_loss: 1.2698 - val_accuracy: 0.7412
# Epoch 6/100
# 97/97 [==============================] - 78s 802ms/step - loss: 0.1203 - accuracy: 0.9598 - val_loss: 1.2986 - val_accuracy: 0.7389
# Epoch 7/100
# 97/97 [==============================] - 78s 804ms/step - loss: 0.1132 - accuracy: 0.9634 - val_loss: 1.3806 - val_accuracy: 0.7351
# Epoch 8/100
# 97/97 [==============================] - 79s 810ms/step - loss: 0
100
# 97/97 [==============================] - 79s 810ms/step - loss: 0.0925 - accuracy: 0.9696 - val_loss: 1.3824 - val_accuracy: 0.7358
# Epoch 86/100
# 97/97 [==============================] - 78s 807ms/step - loss: 0.1025 - accuracy: 0.9676 - val_loss: 1.3142 - val_accuracy: 0.7417
# Epoch 87/100
# 97/97 [==============================] - 79s 811ms/step - loss: 0.0986 - accuracy: 0.9674 - val_loss: 1.3243 - val_accuracy: 0.7413
# Epoch 88/100
# 97/97 [==============================] - 78s 807ms/step - loss: 0.0956 - accuracy: 0.9700 - val_loss: 1.3537 - val_accuracy: 0.7419
# Epoch 89/100
# 97/97 [==============================] - 79s 813ms/step - loss: 0.1015 - accuracy: 0.9666 - val_loss: 1.3515 - val_accuracy: 0.7380
# Epoch 90/100
# 97/97 [==============================] - 79s 813ms/step - loss: 0.1122 - accuracy: 0.9639 - val_loss: 1.2878 - val_accuracy: 0.7354
# Epoch 91/100
# 97/97 [==============================] - 79s 813ms/step - loss: 0.1112 - accuracy: 0.9638 - val_loss: 1.2563 - val_accuracy: 0.7470
# Epoch 92/100
# 97/97 [==============================] - 79s 814ms/step - loss: 0.1112 - accuracy: 0.9634 - val_loss: 1.2794 - val_accuracy: 0.7425
# Epoch 93/100
# 97/97 [==============================] - 78s 808ms/step - loss: 0.1010 - accuracy: 0.9678 - val_loss: 1.2836 - val_accuracy: 0.7387
# Epoch 94/100
# 97/97 [==============================] - 79s 811ms/step - loss: 0.1005 - accuracy: 0.9659 - val_loss: 1.3277 - val_accuracy: 0.7402
# Epoch 95/100
# 97/97 [==============================] - 79s 812ms/step - loss: 0.0953 - accuracy: 0.9692 - val_loss: 1.3343 - val_accuracy: 0.7456
# Epoch 96/100
# 97/97 [==============================] - 78s 808ms/step - loss: 0.1186 - accuracy: 0.9618 - val_loss: 1.2960 - val_accuracy: 0.7350
# Epoch 97/100
# 97/97 [==============================] - 79s 817ms/step - loss: 0.1132 - accuracy: 0.9640 - val_loss: 1.2932 - val_accuracy: 0.7442
# Epoch 98/100
# 97/97 [==============================] - 79s 810ms/step - loss: 0.0979 - accuracy: 0.9686 - val_loss: 1.3400 - val_accuracy: 0.7376
# Epoch 99/100
# 97/97 [==============================] - 79s 810ms/step - loss: 0.1057 - accuracy: 0.9657 - val_loss: 1.2790 - val_accuracy: 0.7432
# Epoch 100/100
# 97/97 [==============================] - 79s 810ms/step - loss: 0.0936 - accuracy: 0.9700 - val_loss: 1.3333 - val_accuracy: 0.7412

# %%
scores = model.evaluate(x_test, y_test)
result_error = str('%.2f'%(1 - scores[1]))
print('Error: ', result_error)
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 1.3989 - accuracy: 0.7405
# Error:  0.26

# %%
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
model_json = model.to_json()
with open("/content/gdrive/My Drive/Colab Notebooks/model_AnneLivia.json" , "w") as json_file:
    json_file.write(model_json)

#serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/model_w_AnneLivia.h5" )
